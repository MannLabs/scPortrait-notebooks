# %% [markdown]
# # Sharded Cytosol Only Cellpose Segmentation

# %%
import os
import numpy as np
import pandas as pd

from scportrait.pipeline.featurization import CellFeaturizer
from scportrait.pipeline.extraction import HDF5CellExtraction
from scportrait.pipeline.project import Project
from scportrait.pipeline.segmentation.workflows import ShardedCytosolOnlySegmentationCellpose
from scportrait.pipeline.selection import LMDSelection

# %%
project_location = "project_sharded_cytosol_only"

project = Project(
    os.path.abspath(project_location),
    config_path="config_example1.yml",
    overwrite=True,
    debug=True,
    segmentation_f=ShardedCytosolOnlySegmentationCellpose,
    extraction_f=HDF5CellExtraction,
    featurization_f=CellFeaturizer,
    selection_f=LMDSelection,
)
# Out:
# Updating project config file.
# [20/03/2025 14:10:43] Loading config from /Users/sophia/Documents/GitHub/scPortrait/examples/notebooks/example_projects/example_1/project_sharded_cytosol_only/config.yml
# [20/03/2025 14:10:43] Initialized temporary directory at /var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./ShardedCytosolOnlySegmentationCellpose_6gul3onq for ShardedCytosolOnlySegmentationCellpose
# [20/03/2025 14:10:43] Compression algorithm for extracted single-cell images: lzf

# %%
from scportrait.data._datasets import dataset_1

dataset_1_path = dataset_1()

# these example images are downloaded from the human protein atlas (www.proteinatlas.org)
images = [f"{dataset_1_path}/Ch1.tif", f"{dataset_1_path}/Ch2.tif", f"{dataset_1_path }/Ch3.tif"]

project.load_input_from_tif_files(images, channel_names=["Hoechst", "Alexa488", "mCherry"])
# Out:
# [20/03/2025 14:08:10] Initialized temporary directory at /Users/sophia/Documents/GitHub/scPortrait/examples/notebooks/example_projects/example_1/Project_fn42aod4 for Project
# [20/03/2025 14:08:11] Image input_image written to sdata object.
# [20/03/2025 14:08:11] Cleaned up temporary directory at <TemporaryDirectory '/Users/sophia/Documents/GitHub/scPortrait/examples/notebooks/example_projects/example_1/Project_fn42aod4'>

# %%
project.plot_input_image()

# %%
project.segment()
# Out:
# [20/03/2025 14:08:23] Mapped input image to memory-mapped array.
# [20/03/2025 14:08:23] Created new shard directory /Users/sophia/Documents/GitHub/scPortrait/examples/notebooks/example_projects/example_1/project_sharded_cytosol_only/segmentation/tiles
# [20/03/2025 14:08:23] target size 2000000 is smaller than input image 9229443. Sharding will be used.
# [20/03/2025 14:08:23] input image 3039 px by 3037 px
# [20/03/2025 14:08:23] target_shard_size: 2000000
# [20/03/2025 14:08:23] sharding plan:
# [20/03/2025 14:08:23] 2 rows by 2 columns
# [20/03/2025 14:08:23] 1519 px by 1518 px
# [20/03/2025 14:08:23] Saving Sharding plan to file: /Users/sophia/Documents/GitHub/scPortrait/examples/notebooks/example_projects/example_1/project_sharded_cytosol_only/segmentation/sharding_plan.csv
# [20/03/2025 14:08:23] Initialized temporary directory at /var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./CytosolOnlySegmentationCellpose_63rjplqa for CytosolOnlySegmentationCellpose
# [20/03/2025 14:08:23] Initialized temporary directory at /var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./CytosolOnlySegmentationCellpose_4fd9l56y for CytosolOnlySegmentationCellpose
# [20/03/2025 14:08:23] Initialized temporary directory at /var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./CytosolOnlySegmentationCellpose_ln7csvyh for CytosolOnlySegmentationCellpose
# [20/03/2025 14:08:23] Initialized temporary directory at /var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./CytosolOnlySegmentationCellpose_ysibnvex for CytosolOnlySegmentationCellpose
# [20/03/2025 14:08:23] sharding plan with 4 elements generated, sharding with 2 threads begins
# [20/03/2025 14:08:23] GPU Status for segmentation is True with 1 GPUs found. Segmentation will be performed on the device mps with 2 processes per device in parallel.
# Segmenting Image Tiles:   0%|          | 0/4 [00:00<?, ?it/s]
# [20/03/2025 14:08:28] Beginning Segmentation of Shard with the slicing (slice(0, 1619, None), slice(0, 1618, None))
# [20/03/2025 14:08:28] Beginning Segmentation of Shard with the slicing (slice(0, 1619, None), slice(1418, 3037, None))
# [20/03/2025 14:08:28] Time taken to load input image: 0.005455500446259975[20/03/2025 14:08:28] Time taken to load input image: 0.005470875184983015
#
# [20/03/2025 14:08:28] GPU Status for segmentation is True and will segment using the following device mps.
# [20/03/2025 14:08:28] GPU Status for segmentation is True with 1 GPUs found. Segmentation will be performed on the device mps with 2 processes per device in parallel.
# [20/03/2025 14:08:28] GPU Status for segmentation is True and will segment using the following device mps.
# [20/03/2025 14:08:28] GPU Status for segmentation is True with 1 GPUs found. Segmentation will be performed on the device mps with 2 processes per device in parallel.
# [20/03/2025 14:08:28] Segmenting cytosol using the following model: cyto2[20/03/2025 14:08:28] Segmenting cytosol using the following model: cyto2
# /Users/sophia/mambaforge/envs/scPortrait_dev/lib/python3.11/site-packages/cellpose/dynamics.py:189: RuntimeWarning: invalid value encountered in divide
#   mu /= (1e-60 + (mu**2).sum(axis=0)**0.5)
# /Users/sophia/mambaforge/envs/scPortrait_dev/lib/python3.11/site-packages/cellpose/dynamics.py:189: RuntimeWarning: invalid value encountered in divide
#   mu /= (1e-60 + (mu**2).sum(axis=0)**0.5)
# [20/03/2025 14:08:35] Filtering status for this segmentation is set to True.
# [20/03/2025 14:08:35] Filtering has been performed during segmentation. Nucleus and Cytosol IDs match. No additional steps are required.
# [20/03/2025 14:08:35] Saved cell_id classes to file /Users/sophia/Documents/GitHub/scPortrait/examples/notebooks/example_projects/example_1/project_sharded_cytosol_only/segmentation/tiles/0/classes.csv.
# [20/03/2025 14:08:35] === Finished segmentation of shard ===
# [20/03/2025 14:08:35] Filtering status for this segmentation is set to True.
# [20/03/2025 14:08:35] Filtering has been performed during segmentation. Nucleus and Cytosol IDs match. No additional steps are required.
# [20/03/2025 14:08:35] Saved cell_id classes to file /Users/sophia/Documents/GitHub/scPortrait/examples/notebooks/example_projects/example_1/project_sharded_cytosol_only/segmentation/tiles/1/classes.csv.
# [20/03/2025 14:08:35] === Finished segmentation of shard ===
# [20/03/2025 14:08:35] Cleaned up temporary directory at <TemporaryDirectory '/var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./CytosolOnlySegmentationCellpose_63rjplqa'>
# [20/03/2025 14:08:35] Segmentation of Shard with the slicing (slice(0, 1619, None), slice(0, 1618, None)) finished
# [20/03/2025 14:08:35] Beginning Segmentation of Shard with the slicing (slice(1419, 3039, None), slice(0, 1618, None))
# [20/03/2025 14:08:35] Time taken to load input image: 0.006779290735721588
# [20/03/2025 14:08:35] Cleaned up temporary directory at <TemporaryDirectory '/var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./CytosolOnlySegmentationCellpose_4fd9l56y'>
# [20/03/2025 14:08:35] GPU Status for segmentation is True and will segment using the following device mps.
# [20/03/2025 14:08:35] GPU Status for segmentation is True with 1 GPUs found. Segmentation will be performed on the device mps with 2 processes per device in parallel.
# [20/03/2025 14:08:35] Segmentation of Shard with the slicing (slice(0, 1619, None), slice(1418, 3037, None)) finished
# [20/03/2025 14:08:35] Beginning Segmentation of Shard with the slicing (slice(1419, 3039, None), slice(1418, 3037, None))
# [20/03/2025 14:08:35] Time taken to load input image: 0.005777082871645689
# [20/03/2025 14:08:35] GPU Status for segmentation is True and will segment using the following device mps.
# [20/03/2025 14:08:35] GPU Status for segmentation is True with 1 GPUs found. Segmentation will be performed on the device mps with 2 processes per device in parallel.
# [20/03/2025 14:08:35] Segmenting cytosol using the following model: cyto2
# [20/03/2025 14:08:35] Segmenting cytosol using the following model: cyto2
# /Users/sophia/mambaforge/envs/scPortrait_dev/lib/python3.11/site-packages/cellpose/dynamics.py:189: RuntimeWarning: invalid value encountered in divide
#   mu /= (1e-60 + (mu**2).sum(axis=0)**0.5)
# /Users/sophia/mambaforge/envs/scPortrait_dev/lib/python3.11/site-packages/cellpose/dynamics.py:189: RuntimeWarning: invalid value encountered in divide
#   mu /= (1e-60 + (mu**2).sum(axis=0)**0.5)
# [20/03/2025 14:08:40] Filtering status for this segmentation is set to True.
# [20/03/2025 14:08:40] Filtering has been performed during segmentation. Nucleus and Cytosol IDs match. No additional steps are required.
# [20/03/2025 14:08:40] Saved cell_id classes to file /Users/sophia/Documents/GitHub/scPortrait/examples/notebooks/example_projects/example_1/project_sharded_cytosol_only/segmentation/tiles/3/classes.csv.
# [20/03/2025 14:08:40] === Finished segmentation of shard ===
# [20/03/2025 14:08:40] Filtering status for this segmentation is set to True.
# [20/03/2025 14:08:40] Filtering has been performed during segmentation. Nucleus and Cytosol IDs match. No additional steps are required.
# [20/03/2025 14:08:40] Saved cell_id classes to file /Users/sophia/Documents/GitHub/scPortrait/examples/notebooks/example_projects/example_1/project_sharded_cytosol_only/segmentation/tiles/2/classes.csv.
# [20/03/2025 14:08:40] === Finished segmentation of shard ===
# [20/03/2025 14:08:40] Cleaned up temporary directory at <TemporaryDirectory '/var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./CytosolOnlySegmentationCellpose_ysibnvex'>
# [20/03/2025 14:08:40] Cleaned up temporary directory at <TemporaryDirectory '/var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./CytosolOnlySegmentationCellpose_ln7csvyh'>
# [20/03/2025 14:08:40] Segmentation of Shard with the slicing (slice(1419, 3039, None), slice(1418, 3037, None)) finished
# [20/03/2025 14:08:40] Segmentation of Shard with the slicing (slice(1419, 3039, None), slice(0, 1618, None)) finished
# [20/03/2025 14:08:41] Finished parallel segmentation
# [20/03/2025 14:08:41] resolve sharding plan
# [20/03/2025 14:08:41] Cleared temporary directory containing input image used for sharding.
# [20/03/2025 14:08:41] Stitching tile 0
# [20/03/2025 14:08:42] Time taken to cleanup overlapping shard regions for shard 0: 0.27563929557800293s
# [20/03/2025 14:08:42] Number of classes contained in shard after processing: 168
# [20/03/2025 14:08:42] Number of Ids in filtered_classes after adding shard 0: 168
# [20/03/2025 14:08:42] Finished stitching tile 0 in 0.9862790107727051 seconds.
# [20/03/2025 14:08:42] Number of filtered classes in Dataset: 168
# [20/03/2025 14:08:42] Filtering status for this segmentation is set to True.
# [20/03/2025 14:08:42] Filtering has been performed during segmentation. Nucleus and Cytosol IDs match. No additional steps are required.
# [20/03/2025 14:08:42] Saved cell_id classes to file /Users/sophia/Documents/GitHub/scPortrait/examples/notebooks/example_projects/example_1/project_sharded_cytosol_only/segmentation/classes.csv.
# [20/03/2025 14:08:42] Stitching tile 1
# [20/03/2025 14:08:42] Time taken to cleanup overlapping shard regions for shard 1: 0.03186917304992676s
# [20/03/2025 14:08:42] Number of classes contained in shard after processing: 138
# [20/03/2025 14:08:42] Number of Ids in filtered_classes after adding shard 1: 278
# [20/03/2025 14:08:42] Finished stitching tile 1 in 0.06504607200622559 seconds.
# [20/03/2025 14:08:42] Number of filtered classes in Dataset: 278
# [20/03/2025 14:08:42] Filtering status for this segmentation is set to True.
# [20/03/2025 14:08:42] Filtering has been performed during segmentation. Nucleus and Cytosol IDs match. No additional steps are required.
# [20/03/2025 14:08:42] Saved cell_id classes to file /Users/sophia/Documents/GitHub/scPortrait/examples/notebooks/example_projects/example_1/project_sharded_cytosol_only/segmentation/classes.csv.
# [20/03/2025 14:08:42] Stitching tile 2
# [20/03/2025 14:08:42] Time taken to cleanup overlapping shard regions for shard 2: 0.03424859046936035s
# [20/03/2025 14:08:42] Number of classes contained in shard after processing: 120
# [20/03/2025 14:08:42] Number of Ids in filtered_classes after adding shard 2: 379
# [20/03/2025 14:08:42] Finished stitching tile 2 in 0.07027912139892578 seconds.
# [20/03/2025 14:08:42] Number of filtered classes in Dataset: 379
# [20/03/2025 14:08:42] Filtering status for this segmentation is set to True.
# [20/03/2025 14:08:42] Filtering has been performed during segmentation. Nucleus and Cytosol IDs match. No additional steps are required.
# [20/03/2025 14:08:42] Saved cell_id classes to file /Users/sophia/Documents/GitHub/scPortrait/examples/notebooks/example_projects/example_1/project_sharded_cytosol_only/segmentation/classes.csv.
# [20/03/2025 14:08:42] Stitching tile 3
# [20/03/2025 14:08:42] Time taken to cleanup overlapping shard regions for shard 3: 0.03479194641113281s
# [20/03/2025 14:08:42] Number of classes contained in shard after processing: 87
# [20/03/2025 14:08:42] Number of Ids in filtered_classes after adding shard 3: 448
# [20/03/2025 14:08:42] Finished stitching tile 3 in 0.07597804069519043 seconds.
# [20/03/2025 14:08:42] Number of filtered classes in Dataset: 448
# [20/03/2025 14:08:42] Filtering status for this segmentation is set to True.
# [20/03/2025 14:08:42] Filtering has been performed during segmentation. Nucleus and Cytosol IDs match. No additional steps are required.
# [20/03/2025 14:08:42] Saved cell_id classes to file /Users/sophia/Documents/GitHub/scPortrait/examples/notebooks/example_projects/example_1/project_sharded_cytosol_only/segmentation/classes.csv.
# [20/03/2025 14:08:42] resolved sharding plan.
# [20/03/2025 14:08:42] Segmentation seg_all_cytosol written to sdata object.
# [20/03/2025 14:08:44] Points centers_seg_all_cytosol written to sdata object.
# [20/03/2025 14:08:44] Cleaned up temporary directory at <TemporaryDirectory '/var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./ShardedCytosolOnlySegmentationCellpose_zny36r3e'>
# [20/03/2025 14:08:44] finished saving segmentation results to sdata object for sharded segmentation.
# [20/03/2025 14:08:44] Deleting intermediate tile results to free up storage space
# [20/03/2025 14:08:44] Total time taken for sharded segmentation: 21.215208834037185 seconds
# [20/03/2025 14:08:44] === finished sharded segmentation ===

# %%
project.plot_segmentation_masks()

# %%
project.extract()
# Out:
# [20/03/2025 14:10:47] Initialized temporary directory at /var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./HDF5CellExtraction_wh6hd0i6 for HDF5CellExtraction
# [20/03/2025 14:10:47] Created new directory for extraction results: /Users/sophia/Documents/GitHub/scPortrait/examples/notebooks/example_projects/example_1/project_sharded_cytosol_only/extraction/data
# [20/03/2025 14:10:47] Setup output folder at /Users/sophia/Documents/GitHub/scPortrait/examples/notebooks/example_projects/example_1/project_sharded_cytosol_only/extraction/data
# [20/03/2025 14:10:47] Found 1 segmentation masks for the given key in the sdata object. Will be extracting single-cell images based on these masks: ['seg_all_cytosol']
# [20/03/2025 14:10:47] Using seg_all_cytosol as the main segmentation mask to determine cell centers.
# [20/03/2025 14:10:47] A total of 9 cells were too close to the image border to be extracted. Their cell_ids were saved to file /Users/sophia/Documents/GitHub/scPortrait/examples/notebooks/example_projects/example_1/project_sharded_cytosol_only/extraction/removed_classes.csv.
# [20/03/2025 14:10:47] Container for single-cell data created.
# [20/03/2025 14:10:47] Extraction Details:
# [20/03/2025 14:10:47] --------------------------------
# [20/03/2025 14:10:47] Number of input image channels: 3
# [20/03/2025 14:10:47] Number of segmentation masks used during extraction: 1
# [20/03/2025 14:10:47] Number of generated output images per cell: 4
# [20/03/2025 14:10:47] Number of unique cells to extract: 439
# [20/03/2025 14:10:47] Extracted Image Dimensions: 128 x 128
# [20/03/2025 14:10:47] Normalization of extracted images: True
# [20/03/2025 14:10:47] Percentile normalization range for single-cell images: [0.01, 0.99]
# [20/03/2025 14:10:47] Starting single-cell image extraction of 439 cells...
# [20/03/2025 14:10:47] Loading input images to memory mapped arrays...
# [20/03/2025 14:10:47] Finished transferring data to memory mapped arrays. Time taken: 0.24 seconds.
# [20/03/2025 14:10:47] Using batch size of 100 for multiprocessing.
# [20/03/2025 14:10:47] Running in multiprocessing mode with 5 threads.
# Extracting cell batches:   0%|          | 0/5 [00:00<?, ?it/s]
# [20/03/2025 14:10:48] Finished extraction in 0.41 seconds (1081.62 cells / second)
# [20/03/2025 14:10:48] Benchmarking times saved to file.
# [20/03/2025 14:10:48] Cleaned up temporary directory at <TemporaryDirectory '/var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./HDF5CellExtraction_wh6hd0i6'>

# %%
project.plot_single_cell_images()

# %%
project.featurize(overwrite = True)
# Out:
# Using extraction directory: /Users/sophia/Documents/GitHub/scPortrait/examples/notebooks/example_projects/example_1/project_sharded_cytosol_only/extraction/data/single_cells.h5sc
# [20/03/2025 14:10:50] Initialized temporary directory at /var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./CellFeaturizer_obfn_k7v for CellFeaturizer
# [20/03/2025 14:10:50] Started CellFeaturization of all available channels.
# [20/03/2025 14:10:50] Created new directory for featurization results: /Users/sophia/Documents/GitHub/scPortrait/examples/notebooks/example_projects/example_1/project_sharded_cytosol_only/featurization/complete_CellFeaturizer
# [20/03/2025 14:10:50] CPU specified in config file but MPS available on system. Consider changing the device for the next run.
# [20/03/2025 14:10:50] Initialized temporary directory at /var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./CellFeaturizer_bovisqwa for CellFeaturizer
# [20/03/2025 14:10:50] Reading data from path: /Users/sophia/Documents/GitHub/scPortrait/examples/notebooks/example_projects/example_1/project_sharded_cytosol_only/extraction/data/single_cells.h5sc
# [20/03/2025 14:10:50] Processing dataset with 439 cells
# [20/03/2025 14:10:50] Dataloader generated with a batchsize of 900 and 10 workers. Dataloader contains 1 entries.
# [20/03/2025 14:10:50] Started processing of 1 batches.
# [20/03/2025 14:10:51] finished processing.
# [20/03/2025 14:10:51] Results saved to file: /Users/sophia/Documents/GitHub/scPortrait/examples/notebooks/example_projects/example_1/project_sharded_cytosol_only/featurization/complete_CellFeaturizer/calculated_image_features.csv
# [20/03/2025 14:10:51] Table CellFeaturizer__cytosol written to sdata object.
# [20/03/2025 14:10:51] GPU memory before performing cleanup: None
# [20/03/2025 14:10:51] GPU memory after performing cleanup: None
# [20/03/2025 14:10:51] Cleaned up temporary directory at <TemporaryDirectory '/var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./CellFeaturizer_bovisqwa'>

# %%
# load classification results
results = pd.read_csv(f"{project_location}/featurization/complete_CellFeaturizer/calculated_image_features.csv")
results
# Out:
#      cytosol_area  Hoechst_mean_cytosol  Hoechst_median_cytosol  \
# 0          6971.0              0.074123                     0.0
# 1          3870.0              0.055529                     0.0
# 2          3324.0              0.045754                     0.0
# 3          5520.0              0.058031                     0.0
# 4          4273.0              0.059866                     0.0
# ..            ...                   ...                     ...
# 434        6132.0              0.055159                     0.0
# 435        4216.0              0.034669                     0.0
# 436        5577.0              0.038588                     0.0
# 437        5600.0              0.051918                     0.0
# 438        5278.0              0.044378                     0.0
#
#      Hoechst_quant75_cytosol  Hoechst_quant25_cytosol  \
# 0                   0.026508                      0.0
# 1                   0.000000                      0.0
# 2                   0.000000                      0.0
# 3                   0.009991                      0.0
# 4                   0.000001                      0.0
# ..                       ...                      ...
# 434                 0.002701                      0.0
# 435                 0.000000                      0.0
# 436                 0.001784                      0.0
# 437                 0.002636                      0.0
# 438                 0.000638                      0.0
#
#      Hoechst_summed_intensity_cytosol  \
# 0                          1214.43900
# 1                           909.77954
# 2                           749.64100
# 3                           950.77344
# 4                           980.83813
# ..                                ...
# 434                         903.71790
# 435                         568.01700
# 436                         632.22380
# 437                         850.62177
# 438                         727.08490
#
#      Hoechst_summed_intensity_area_normalized_cytosol  Alexa488_mean_cytosol  \
# 0                                            0.174213               0.241501
# 1                                            0.235085               0.110968
# 2                                            0.225524               0.100493
# 3                                            0.172242               0.177036
# 4                                            0.229543               0.127818
# ..                                                ...                    ...
# 434                                          0.147377               0.221340
# 435                                          0.134729               0.142166
# 436                                          0.113363               0.203732
# 437                                          0.151897               0.177957
# 438                                          0.137758               0.168211
#
#      Alexa488_median_cytosol  Alexa488_quant75_cytosol  ...  \
# 0                        0.0              6.796875e-01  ...
# 1                        0.0              0.000000e+00  ...
# 2                        0.0              0.000000e+00  ...
# 3                        0.0              1.333923e-01  ...
# 4                        0.0              1.743436e-06  ...
# ..                       ...                       ...  ...
# 434                      0.0              5.996094e-01  ...
# 435                      0.0              2.980232e-07  ...
# 436                      0.0              2.258911e-01  ...
# 437                      0.0              3.471069e-01  ...
# 438                      0.0              3.302002e-02  ...
#
#      Alexa488_summed_intensity_cytosol  \
# 0                            3956.7534
# 1                            1818.0989
# 2                            1646.4695
# 3                            2900.5632
# 4                            2094.1648
# ..                                 ...
# 434                          3626.4424
# 435                          2329.2505
# 436                          3337.9420
# 437                          2915.6428
# 438                          2755.9630
#
#      Alexa488_summed_intensity_area_normalized_cytosol  mCherry_mean_cytosol  \
# 0                                             0.567602              0.139420
# 1                                             0.469793              0.102785
# 2                                             0.495328              0.090616
# 3                                             0.525464              0.134659
# 4                                             0.490092              0.106930
# ..                                                 ...                   ...
# 434                                           0.591396              0.136811
# 435                                           0.552479              0.095614
# 436                                           0.598519              0.124443
# 437                                           0.520651              0.133997
# 438                                           0.522161              0.128799
#
#      mCherry_median_cytosol  mCherry_quant75_cytosol  mCherry_quant25_cytosol  \
# 0                       0.0             1.658936e-01                      0.0
# 1                       0.0             0.000000e+00                      0.0
# 2                       0.0             0.000000e+00                      0.0
# 3                       0.0             1.993179e-02                      0.0
# 4                       0.0             6.556511e-07                      0.0
# ..                      ...                      ...                      ...
# 434                     0.0             6.333923e-02                      0.0
# 435                     0.0             5.960465e-08                      0.0
# 436                     0.0             1.167488e-02                      0.0
# 437                     0.0             4.885864e-02                      0.0
# 438                     0.0             3.452778e-03                      0.0
#
#      mCherry_summed_intensity_cytosol  \
# 0                           2284.2634
# 1                           1684.0374
# 2                           1484.6489
# 3                           2206.2510
# 4                           1751.9409
# ..                                ...
# 434                         2241.5059
# 435                         1566.5356
# 436                         2038.8794
# 437                         2195.4038
# 438                         2110.2441
#
#      mCherry_summed_intensity_area_normalized_cytosol  label  cell_id
# 0                                            0.327681      0       11
# 1                                            0.435152      0       13
# 2                                            0.446645      0       15
# 3                                            0.399683      0       16
# 4                                            0.410003      0       17
# ..                                                ...    ...      ...
# 434                                          0.365542      0     1277
# 435                                          0.371569      0     1278
# 436                                          0.365587      0     1279
# 437                                          0.392036      0     1280
# 438                                          0.399819      0     1281
#
# [439 rows x 21 columns]

# %%
#test selection workflow
selected_cells_large = results[results.cytosol_area > 4500]["cell_id"].tolist()
selected_cells_small = results[results.cytosol_area < 3000]["cell_id"].tolist()

cells_to_select = [
    {"name": "large_cells", "classes": selected_cells_large, "well": "A1"},
    {"name": "small_cells", "classes": selected_cells_small, "well": "B1"},
]

marker_0 = (0, 0)
marker_1 = (2000, 0)
marker_2 = (0, 2000)

calibration_marker = np.array([marker_0, marker_1, marker_2])

# %%
project.selection_f.segmentation_channel_to_select = "seg_all_cytosol" #update to the correct channel for this notebook with out loading a different config
project.select(cells_to_select, calibration_marker)
# Out:
# [20/03/2025 14:11:03] Initialized temporary directory at /var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./LMDSelection_jfq1z73i for LMDSelection
# [20/03/2025 14:11:03] Selection process started.
# Processing cell batches:   0%|          | 0/3 [00:00<?, ?it/s]
# [20/03/2025 14:11:09] Temporary directory not found, skipping cleanup
# [20/03/2025 14:11:09] Temporary directory not found, skipping cleanup
# [20/03/2025 14:11:09] Temporary directory not found, skipping cleanup
# [20/03/2025 14:11:10] Coordinate lookup index calculation took 7.754024249967188 seconds.
# No configuration for shape_erosion found, parameter will be set to 0
# No configuration for binary_smoothing found, parameter will be set to 3
# No configuration for convolution_smoothing found, parameter will be set to 15
# No configuration for rdp_epsilon found, parameter will be set to 0.1
# No configuration for xml_decimal_transform found, parameter will be set to 100
# No configuration for distance_heuristic found, parameter will be set to 300
# No configuration for join_intersecting found, parameter will be set to True
# Path optimizer used for XML generation: hilbert
# cell set 0 passed sanity check
# cell set 1 passed sanity check
# Loading coordinates from external source
# Processing cell sets in parallel
# collecting cell sets:   0%|          | 0/2 [00:00<?, ?it/s]
# Convert label format into coordinate format
# Convert label format into coordinate format
# Conversion finished, performing sanity check.
# Intersecting Shapes will be merged into a single shape.
# Conversion finished, performing sanity check.
# Intersecting Shapes will be merged into a single shape.
# dilating shapes: 100%|██████████| 57/57 [00:03<00:00, 15.71it/s]
# dilating shapes: 100%|██████████| 204/204 [00:03<00:00, 52.81it/s]
# 0 shapes that were intersecting were found and merged.
# creating shapes: 100%|██████████| 36/36 [00:01<00:00, 19.76it/s]
# calculating polygons:   0%|          | 0/36 [00:00<?, ?it/s]
# 0 shapes that were intersecting were found and merged.
# calculating polygons: 100%|██████████| 36/36 [00:03<00:00,  9.45it/s]
# creating shapes:   1%|          | 1/84 [00:02<03:53,  2.81s/it]
# Current path length: 23,941.74 units
# creating shapes: 100%|██████████| 84/84 [00:02<00:00, 28.35it/s]
# calculating polygons:   0%|          | 0/84 [00:00<?, ?it/s]
# Optimized path length: 16,056.97 units
# Optimization factor: 1.5x
# Plotting shapes in debug mode is not supported in multi-threading mode.
# Saving plots to disk instead.
# calculating polygons: 100%|██████████| 84/84 [00:06<00:00, 12.27it/s]
# Current path length: 50,695.45 units
# Optimized path length: 27,477.05 units
# Optimization factor: 1.8x
# Plotting shapes in debug mode is not supported in multi-threading mode.
# Saving plots to disk instead.
# ===== Collection Stats =====
# Number of shapes: 120
# Number of vertices: 16,682
# ============================
# Mean vertices: 139
# Min vertices: 62
# 5% percentile vertices: 75
# Median vertices: 103
# 95% percentile vertices: 314
# Max vertices: 705
# [0 0]
# [      0 -200000]
# [200000      0]
# [20/03/2025 14:11:30] Saved output at /Users/sophia/Documents/GitHub/scPortrait/examples/notebooks/example_projects/example_1/project_sharded_cytosol_only/selection/large_cells_small_cells.xml
# [20/03/2025 14:11:30] Cleaned up temporary directory at <TemporaryDirectory '/var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./LMDSelection_jfq1z73i'>
