# %% [markdown]
# # Sharded Cytosol Only Cellpose Segmentation

# %%
import os
import numpy as np
import pandas as pd

from scportrait.pipeline.featurization import CellFeaturizer
from scportrait.pipeline.extraction import HDF5CellExtraction
from scportrait.pipeline.project import Project
from scportrait.pipeline.segmentation.workflows import ShardedCytosolOnlySegmentationCellpose
from scportrait.pipeline.selection import LMDSelection
import scportrait

# %%
project_location = "project_sharded_cytosol_only"
config_path = scportrait.data.get_config_file(config_id = "dataset_1_config")

project = Project(
    os.path.abspath(project_location),
    config_path=config_path,
    overwrite=True,
    debug=True,
    segmentation_f=ShardedCytosolOnlySegmentationCellpose,
    extraction_f=HDF5CellExtraction,
    featurization_f=CellFeaturizer,
    selection_f=LMDSelection,
)
# Out:
# Updating project config file.
# [10/04/2025 18:41:52] Loading config from /Users/sophia/Documents/GitHub/scPortrait/examples/notebooks/example_projects/example_1/project_sharded/config.yml
# [10/04/2025 18:41:52] Initialized temporary directory at /var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./ShardedCytosolOnlySegmentationCellpose_k37v7xyt for ShardedCytosolOnlySegmentationCellpose
# [10/04/2025 18:41:52] Compression algorithm for extracted single-cell images: lzf

# %%
dataset_1_path = scportrait.data.dataset_1()

# these example images are downloaded from the human protein atlas (www.proteinatlas.org)
images = [f"{dataset_1_path}/Ch1.tif", f"{dataset_1_path}/Ch2.tif", f"{dataset_1_path }/Ch3.tif"]

project.load_input_from_tif_files(images, channel_names=["Hoechst", "Alexa488", "mCherry"])
# Out:
# [10/04/2025 18:41:57] Output location /Users/sophia/Documents/GitHub/scPortrait/examples/notebooks/example_projects/example_1/project_sharded/scportrait.sdata already exists. Overwriting.
# INFO     The Zarr backing store has been changed from None the new file path:
#          /Users/sophia/Documents/GitHub/scPortrait/examples/notebooks/example_projects/example_1/project_sharded/sc
#          portrait.sdata
# [10/04/2025 18:41:57] Initialized temporary directory at /Users/sophia/Documents/GitHub/scPortrait/examples/notebooks/example_projects/example_1/Project_3q99_247 for Project
# [10/04/2025 18:41:58] Image input_image written to sdata object.
# [10/04/2025 18:41:58] Cleaned up temporary directory at <TemporaryDirectory '/Users/sophia/Documents/GitHub/scPortrait/examples/notebooks/example_projects/example_1/Project_3q99_247'>

# %%
project.plot_input_image()

# %%
project.segment()
# Out:
# [10/04/2025 18:42:01] Mapped input image to memory-mapped array.
# [10/04/2025 18:42:01] Created new shard directory /Users/sophia/Documents/GitHub/scPortrait/examples/notebooks/example_projects/example_1/project_sharded/segmentation/tiles
# [10/04/2025 18:42:01] sharding plan already found in directory /Users/sophia/Documents/GitHub/scPortrait/examples/notebooks/example_projects/example_1/project_sharded/segmentation/sharding_plan.csv.
# [10/04/2025 18:42:01] Overwriting existing sharding plan.
# [10/04/2025 18:42:01] target size 2000000 is smaller than input image 9229443. Sharding will be used.
# [10/04/2025 18:42:01] input image 3039 px by 3037 px
# [10/04/2025 18:42:01] target_shard_size: 2000000
# [10/04/2025 18:42:01] sharding plan:
# [10/04/2025 18:42:01] 2 rows by 2 columns
# [10/04/2025 18:42:01] 1519 px by 1518 px
# [10/04/2025 18:42:01] Saving Sharding plan to file: /Users/sophia/Documents/GitHub/scPortrait/examples/notebooks/example_projects/example_1/project_sharded/segmentation/sharding_plan.csv
# [10/04/2025 18:42:01] Initialized temporary directory at /var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./CytosolOnlySegmentationCellpose_4wcqw3su for CytosolOnlySegmentationCellpose
# [10/04/2025 18:42:01] Initialized temporary directory at /var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./CytosolOnlySegmentationCellpose_e60ez4ny for CytosolOnlySegmentationCellpose
# [10/04/2025 18:42:01] Initialized temporary directory at /var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./CytosolOnlySegmentationCellpose_x3_qjcet for CytosolOnlySegmentationCellpose
# [10/04/2025 18:42:01] Initialized temporary directory at /var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./CytosolOnlySegmentationCellpose_67q6udoe for CytosolOnlySegmentationCellpose
# [10/04/2025 18:42:01] sharding plan with 4 elements generated, sharding with 2 threads begins
# [10/04/2025 18:42:01] GPU Status for segmentation is True with 1 GPUs found. Segmentation will be performed on the device mps with 2 processes per device in parallel.
# Segmenting Image Tiles:   0%|          | 0/4 [00:00<?, ?it/s]
# [10/04/2025 18:42:06] Beginning Segmentation of Shard with the slicing (slice(0, 1619, None), slice(1418, 3037, None))
# [10/04/2025 18:42:06] Beginning Segmentation of Shard with the slicing (slice(0, 1619, None), slice(0, 1618, None))
# [10/04/2025 18:42:06] Time taken to load input image: 0.0056508339766878635
# [10/04/2025 18:42:06] Time taken to load input image: 0.005600708012934774
# [10/04/2025 18:42:06] GPU Status for segmentation is True and will segment using the following device mps.
# [10/04/2025 18:42:06] GPU Status for segmentation is True and will segment using the following device mps.
# [10/04/2025 18:42:06] GPU Status for segmentation is True with 1 GPUs found. Segmentation will be performed on the device mps with 2 processes per device in parallel.
# [10/04/2025 18:42:06] GPU Status for segmentation is True with 1 GPUs found. Segmentation will be performed on the device mps with 2 processes per device in parallel.
# [10/04/2025 18:42:06] Segmenting cytosol using the following model: cyto2[10/04/2025 18:42:06] Segmenting cytosol using the following model: cyto2
#
# [10/04/2025 18:42:19] Filtering status for this segmentation is set to True.
# [10/04/2025 18:42:19] Filtering has been performed during segmentation. Nucleus and Cytosol IDs match. No additional steps are required.
# [10/04/2025 18:42:19] Saved cell_id classes to file /Users/sophia/Documents/GitHub/scPortrait/examples/notebooks/example_projects/example_1/project_sharded/segmentation/tiles/1/classes.csv.
# [10/04/2025 18:42:19] === Finished segmentation of shard ===
# [10/04/2025 18:42:19] Cleaned up temporary directory at <TemporaryDirectory '/var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./CytosolOnlySegmentationCellpose_e60ez4ny'>
# [10/04/2025 18:42:19] Segmentation of Shard with the slicing (slice(0, 1619, None), slice(1418, 3037, None)) finished
# [10/04/2025 18:42:19] Beginning Segmentation of Shard with the slicing (slice(1419, 3039, None), slice(0, 1618, None))
# [10/04/2025 18:42:19] Time taken to load input image: 0.004928583017317578
# [10/04/2025 18:42:19] GPU Status for segmentation is True and will segment using the following device mps.
# [10/04/2025 18:42:19] GPU Status for segmentation is True with 1 GPUs found. Segmentation will be performed on the device mps with 2 processes per device in parallel.
# [10/04/2025 18:42:19] Filtering status for this segmentation is set to True.
# [10/04/2025 18:42:19] Filtering has been performed during segmentation. Nucleus and Cytosol IDs match. No additional steps are required.
# [10/04/2025 18:42:19] Saved cell_id classes to file /Users/sophia/Documents/GitHub/scPortrait/examples/notebooks/example_projects/example_1/project_sharded/segmentation/tiles/0/classes.csv.
# [10/04/2025 18:42:19] === Finished segmentation of shard ===
# [10/04/2025 18:42:19] Cleaned up temporary directory at <TemporaryDirectory '/var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./CytosolOnlySegmentationCellpose_4wcqw3su'>
# [10/04/2025 18:42:19] Segmenting cytosol using the following model: cyto2
# [10/04/2025 18:42:19] Segmentation of Shard with the slicing (slice(0, 1619, None), slice(0, 1618, None)) finished
# [10/04/2025 18:42:19] Beginning Segmentation of Shard with the slicing (slice(1419, 3039, None), slice(1418, 3037, None))
# [10/04/2025 18:42:19] Time taken to load input image: 0.004869750002399087
# [10/04/2025 18:42:19] GPU Status for segmentation is True and will segment using the following device mps.
# [10/04/2025 18:42:19] GPU Status for segmentation is True with 1 GPUs found. Segmentation will be performed on the device mps with 2 processes per device in parallel.
# [10/04/2025 18:42:20] Segmenting cytosol using the following model: cyto2
# [10/04/2025 18:42:28] Filtering status for this segmentation is set to True.
# [10/04/2025 18:42:28] Filtering has been performed during segmentation. Nucleus and Cytosol IDs match. No additional steps are required.
# [10/04/2025 18:42:28] Saved cell_id classes to file /Users/sophia/Documents/GitHub/scPortrait/examples/notebooks/example_projects/example_1/project_sharded/segmentation/tiles/3/classes.csv.
# [10/04/2025 18:42:28] === Finished segmentation of shard ===
# [10/04/2025 18:42:28] Filtering status for this segmentation is set to True.
# [10/04/2025 18:42:28] Filtering has been performed during segmentation. Nucleus and Cytosol IDs match. No additional steps are required.
# [10/04/2025 18:42:28] Saved cell_id classes to file /Users/sophia/Documents/GitHub/scPortrait/examples/notebooks/example_projects/example_1/project_sharded/segmentation/tiles/2/classes.csv.
# [10/04/2025 18:42:28] === Finished segmentation of shard ===
# [10/04/2025 18:42:28] Cleaned up temporary directory at <TemporaryDirectory '/var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./CytosolOnlySegmentationCellpose_67q6udoe'>
# [10/04/2025 18:42:28] Cleaned up temporary directory at <TemporaryDirectory '/var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./CytosolOnlySegmentationCellpose_x3_qjcet'>
# [10/04/2025 18:42:28] Segmentation of Shard with the slicing (slice(1419, 3039, None), slice(1418, 3037, None)) finished
# [10/04/2025 18:42:28] Segmentation of Shard with the slicing (slice(1419, 3039, None), slice(0, 1618, None)) finished
# [10/04/2025 18:42:29] Finished parallel segmentation
# [10/04/2025 18:42:29] resolve sharding plan
# [10/04/2025 18:42:29] Cleared temporary directory containing input image used for sharding.
# [10/04/2025 18:42:29] Stitching tile 0
# [10/04/2025 18:42:30] Time taken to cleanup overlapping shard regions for shard 0: 0.2614717483520508s
# [10/04/2025 18:42:30] Number of classes contained in shard after processing: 168
# [10/04/2025 18:42:30] Number of Ids in filtered_classes after adding shard 0: 168
# [10/04/2025 18:42:30] Finished stitching tile 0 in 0.9806551933288574 seconds.
# [10/04/2025 18:42:30] Number of filtered classes in Dataset: 168
# [10/04/2025 18:42:30] Filtering status for this segmentation is set to True.
# [10/04/2025 18:42:30] Filtering has been performed during segmentation. Nucleus and Cytosol IDs match. No additional steps are required.
# [10/04/2025 18:42:30] Saved cell_id classes to file /Users/sophia/Documents/GitHub/scPortrait/examples/notebooks/example_projects/example_1/project_sharded/segmentation/classes.csv.
# [10/04/2025 18:42:30] Stitching tile 1
# [10/04/2025 18:42:30] Time taken to cleanup overlapping shard regions for shard 1: 0.032335758209228516s
# [10/04/2025 18:42:30] Number of classes contained in shard after processing: 139
# [10/04/2025 18:42:30] Number of Ids in filtered_classes after adding shard 1: 279
# [10/04/2025 18:42:30] Finished stitching tile 1 in 0.07250380516052246 seconds.
# [10/04/2025 18:42:30] Number of filtered classes in Dataset: 279
# [10/04/2025 18:42:30] Filtering status for this segmentation is set to True.
# [10/04/2025 18:42:30] Filtering has been performed during segmentation. Nucleus and Cytosol IDs match. No additional steps are required.
# [10/04/2025 18:42:30] Saved cell_id classes to file /Users/sophia/Documents/GitHub/scPortrait/examples/notebooks/example_projects/example_1/project_sharded/segmentation/classes.csv.
# [10/04/2025 18:42:30] Stitching tile 2
# [10/04/2025 18:42:30] Time taken to cleanup overlapping shard regions for shard 2: 0.03256392478942871s
# [10/04/2025 18:42:30] Number of classes contained in shard after processing: 120
# [10/04/2025 18:42:30] Number of Ids in filtered_classes after adding shard 2: 380
# [10/04/2025 18:42:30] Finished stitching tile 2 in 0.07386302947998047 seconds.
# [10/04/2025 18:42:30] Number of filtered classes in Dataset: 380
# [10/04/2025 18:42:30] Filtering status for this segmentation is set to True.
# [10/04/2025 18:42:30] Filtering has been performed during segmentation. Nucleus and Cytosol IDs match. No additional steps are required.
# [10/04/2025 18:42:30] Saved cell_id classes to file /Users/sophia/Documents/GitHub/scPortrait/examples/notebooks/example_projects/example_1/project_sharded/segmentation/classes.csv.
# [10/04/2025 18:42:30] Stitching tile 3
# [10/04/2025 18:42:31] Time taken to cleanup overlapping shard regions for shard 3: 0.02872490882873535s
# [10/04/2025 18:42:31] Number of classes contained in shard after processing: 87
# [10/04/2025 18:42:31] Number of Ids in filtered_classes after adding shard 3: 448
# [10/04/2025 18:42:31] Finished stitching tile 3 in 0.06662821769714355 seconds.
# [10/04/2025 18:42:31] Number of filtered classes in Dataset: 448
# [10/04/2025 18:42:31] Filtering status for this segmentation is set to True.
# [10/04/2025 18:42:31] Filtering has been performed during segmentation. Nucleus and Cytosol IDs match. No additional steps are required.
# [10/04/2025 18:42:31] Saved cell_id classes to file /Users/sophia/Documents/GitHub/scPortrait/examples/notebooks/example_projects/example_1/project_sharded/segmentation/classes.csv.
# [10/04/2025 18:42:31] resolved sharding plan.
# [10/04/2025 18:42:31] Segmentation seg_all_cytosol written to sdata object.
# [10/04/2025 18:42:33] Points centers_seg_all_cytosol written to sdata object.
# [10/04/2025 18:42:33] Cleaned up temporary directory at <TemporaryDirectory '/var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./ShardedCytosolOnlySegmentationCellpose_k37v7xyt'>
# [10/04/2025 18:42:33] finished saving segmentation results to sdata object for sharded segmentation.
# [10/04/2025 18:42:33] Deleting intermediate tile results to free up storage space
# [10/04/2025 18:42:33] Total time taken for sharded segmentation: 32.52271804198972 seconds
# [10/04/2025 18:42:33] === finished sharded segmentation ===

# %%
project.plot_segmentation_masks()

# %%
project.extract()
# Out:
# [10/04/2025 18:42:34] Initialized temporary directory at /var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./HDF5CellExtraction_caszrr2b for HDF5CellExtraction
# [10/04/2025 18:42:34] Created new directory for extraction results: /Users/sophia/Documents/GitHub/scPortrait/examples/notebooks/example_projects/example_1/project_sharded/extraction/data
# [10/04/2025 18:42:34] Setup output folder at /Users/sophia/Documents/GitHub/scPortrait/examples/notebooks/example_projects/example_1/project_sharded/extraction/data
# [10/04/2025 18:42:34] Found 1 segmentation masks for the given key in the sdata object. Will be extracting single-cell images based on these masks: ['seg_all_cytosol']
# [10/04/2025 18:42:34] Using seg_all_cytosol as the main segmentation mask to determine cell centers.
# [10/04/2025 18:42:34] A total of 10 cells were too close to the image border to be extracted. Their cell_ids were saved to file /Users/sophia/Documents/GitHub/scPortrait/examples/notebooks/example_projects/example_1/project_sharded/extraction/removed_classes.csv.
# [10/04/2025 18:42:34] Container for single-cell data created.
# [10/04/2025 18:42:34] Extraction Details:
# [10/04/2025 18:42:34] --------------------------------
# [10/04/2025 18:42:34] Number of input image channels: 3
# [10/04/2025 18:42:34] Number of segmentation masks used during extraction: 1
# [10/04/2025 18:42:34] Number of generated output images per cell: 4
# [10/04/2025 18:42:34] Number of unique cells to extract: 438
# [10/04/2025 18:42:34] Extracted Image Dimensions: 128 x 128
# [10/04/2025 18:42:34] Normalization of extracted images: True
# [10/04/2025 18:42:34] Percentile normalization range for single-cell images: [0.01, 0.99]
# [10/04/2025 18:42:34] Starting single-cell image extraction of 438 cells...
# [10/04/2025 18:42:34] Loading input images to memory mapped arrays...
# [10/04/2025 18:42:35] Finished transferring data to memory mapped arrays. Time taken: 0.38 seconds.
# [10/04/2025 18:42:35] Using batch size of 100 for multiprocessing.
# [10/04/2025 18:42:35] Running in multiprocessing mode with 5 threads.
# Extracting cell batches:   0%|          | 0/5 [00:00<?, ?it/s]
# [10/04/2025 18:42:35] Finished extraction in 0.47 seconds (930.29 cells / second)
# [10/04/2025 18:42:35] Benchmarking times saved to file.
# [10/04/2025 18:42:35] Cleaned up temporary directory at <TemporaryDirectory '/var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./HDF5CellExtraction_caszrr2b'>

# %%
project.plot_single_cell_images()

# %%
project.featurize(overwrite = True)
# Out:
# Using extraction directory: /Users/sophia/Documents/GitHub/scPortrait/examples/notebooks/example_projects/example_1/project_sharded/extraction/data/single_cells.h5sc
# [10/04/2025 18:42:36] Initialized temporary directory at /var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./CellFeaturizer_byfv21mk for CellFeaturizer
# [10/04/2025 18:42:36] Started CellFeaturization of all available channels.
# [10/04/2025 18:42:36] Overwrite flag is set, deleting existing directory for featurization results.
# [10/04/2025 18:42:36] Created new directory for featurization results: /Users/sophia/Documents/GitHub/scPortrait/examples/notebooks/example_projects/example_1/project_sharded/featurization/complete_CellFeaturizer
# [10/04/2025 18:42:36] CPU specified in config file but MPS available on system. Consider changing the device for the next run.
# [10/04/2025 18:42:36] Initialized temporary directory at /var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./CellFeaturizer_9cgol7v2 for CellFeaturizer
# [10/04/2025 18:42:36] Reading data from path: /Users/sophia/Documents/GitHub/scPortrait/examples/notebooks/example_projects/example_1/project_sharded/extraction/data/single_cells.h5sc
# [10/04/2025 18:42:36] Processing dataset with 438 cells
# [10/04/2025 18:42:36] Dataloader generated with a batchsize of 900 and 10 workers. Dataloader contains 1 entries.
# [10/04/2025 18:42:36] Started processing of 1 batches.
# [10/04/2025 18:42:37] finished processing.
# [10/04/2025 18:42:37] Results saved to file: /Users/sophia/Documents/GitHub/scPortrait/examples/notebooks/example_projects/example_1/project_sharded/featurization/complete_CellFeaturizer/calculated_image_features.csv
# [10/04/2025 18:42:37] Table CellFeaturizer_cytosol written to sdata object.
# [10/04/2025 18:42:37] GPU memory before performing cleanup: None
# [10/04/2025 18:42:37] GPU memory after performing cleanup: None
# [10/04/2025 18:42:37] Cleaned up temporary directory at <TemporaryDirectory '/var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./CellFeaturizer_9cgol7v2'>

# %%
# load classification results
results = project.sdata['CellFeaturizer_cytosol'].to_df().merge(project.sdata['CellFeaturizer_cytosol'].obs, left_index=True, right_index=True).drop(columns = "region")
results
# Out:
#      cytosol_area  Hoechst_mean_cytosol  Hoechst_median_cytosol  \
# 0          6971.0              0.074123                     0.0
# 1          3870.0              0.055529                     0.0
# 2          3324.0              0.045754                     0.0
# 3          5520.0              0.058031                     0.0
# 4          4273.0              0.059866                     0.0
# ..            ...                   ...                     ...
# 433        6132.0              0.055159                     0.0
# 434        4216.0              0.034669                     0.0
# 435        5577.0              0.038588                     0.0
# 436        5600.0              0.051918                     0.0
# 437        5278.0              0.044378                     0.0
#
#      Hoechst_quant75_cytosol  Hoechst_quant25_cytosol  \
# 0                   0.026508                      0.0
# 1                   0.000000                      0.0
# 2                   0.000000                      0.0
# 3                   0.009991                      0.0
# 4                   0.000001                      0.0
# ..                       ...                      ...
# 433                 0.002701                      0.0
# 434                 0.000000                      0.0
# 435                 0.001784                      0.0
# 436                 0.002636                      0.0
# 437                 0.000638                      0.0
#
#      Hoechst_summed_intensity_cytosol  \
# 0                         1214.438965
# 1                          909.779541
# 2                          749.640991
# 3                          950.773438
# 4                          980.838135
# ..                                ...
# 433                        903.717896
# 434                        568.017029
# 435                        632.223816
# 436                        850.621765
# 437                        727.084900
#
#      Hoechst_summed_intensity_area_normalized_cytosol  Alexa488_mean_cytosol  \
# 0                                            0.174213               0.241501
# 1                                            0.235085               0.110968
# 2                                            0.225524               0.100493
# 3                                            0.172242               0.177036
# 4                                            0.229543               0.127818
# ..                                                ...                    ...
# 433                                          0.147377               0.221340
# 434                                          0.134729               0.142166
# 435                                          0.113363               0.203732
# 436                                          0.151897               0.177957
# 437                                          0.137758               0.168211
#
#      Alexa488_median_cytosol  Alexa488_quant75_cytosol  \
# 0                        0.0              6.796875e-01
# 1                        0.0              0.000000e+00
# 2                        0.0              0.000000e+00
# 3                        0.0              1.333923e-01
# 4                        0.0              1.743436e-06
# ..                       ...                       ...
# 433                      0.0              5.996094e-01
# 434                      0.0              2.980232e-07
# 435                      0.0              2.258911e-01
# 436                      0.0              3.471069e-01
# 437                      0.0              3.302002e-02
#
#      Alexa488_quant25_cytosol  Alexa488_summed_intensity_cytosol  \
# 0                         0.0                        3956.753418
# 1                         0.0                        1818.098877
# 2                         0.0                        1646.469482
# 3                         0.0                        2900.563232
# 4                         0.0                        2094.164795
# ..                        ...                                ...
# 433                       0.0                        3626.442383
# 434                       0.0                        2329.250488
# 435                       0.0                        3337.941895
# 436                       0.0                        2915.642822
# 437                       0.0                        2755.962891
#
#      Alexa488_summed_intensity_area_normalized_cytosol  mCherry_mean_cytosol  \
# 0                                             0.567602              0.139420
# 1                                             0.469793              0.102785
# 2                                             0.495328              0.090616
# 3                                             0.525464              0.134659
# 4                                             0.490092              0.106930
# ..                                                 ...                   ...
# 433                                           0.591396              0.136811
# 434                                           0.552479              0.095614
# 435                                           0.598519              0.124443
# 436                                           0.520651              0.133997
# 437                                           0.522160              0.128799
#
#      mCherry_median_cytosol  mCherry_quant75_cytosol  mCherry_quant25_cytosol  \
# 0                       0.0             1.658936e-01                      0.0
# 1                       0.0             0.000000e+00                      0.0
# 2                       0.0             0.000000e+00                      0.0
# 3                       0.0             1.993179e-02                      0.0
# 4                       0.0             6.556511e-07                      0.0
# ..                      ...                      ...                      ...
# 433                     0.0             6.333923e-02                      0.0
# 434                     0.0             5.960464e-08                      0.0
# 435                     0.0             1.167488e-02                      0.0
# 436                     0.0             4.885864e-02                      0.0
# 437                     0.0             3.452778e-03                      0.0
#
#      mCherry_summed_intensity_cytosol  \
# 0                         2284.263428
# 1                         1684.037354
# 2                         1484.648926
# 3                         2206.250977
# 4                         1751.940918
# ..                                ...
# 433                       2241.505859
# 434                       1566.535645
# 435                       2038.879395
# 436                       2195.403809
# 437                       2110.244141
#
#      mCherry_summed_intensity_area_normalized_cytosol  scportrait_cell_id
# 0                                            0.327681                  11
# 1                                            0.435152                  13
# 2                                            0.446645                  15
# 3                                            0.399683                  16
# 4                                            0.410003                  17
# ..                                                ...                 ...
# 433                                          0.365542                1284
# 434                                          0.371569                1285
# 435                                          0.365587                1286
# 436                                          0.392036                1287
# 437                                          0.399819                1288
#
# [438 rows x 20 columns]

# %%
#test selection workflow
selected_cells_large = results[results.cytosol_area > 4500]["scportrait_cell_id"].tolist()
selected_cells_small = results[results.cytosol_area < 3000]["scportrait_cell_id"].tolist()

cells_to_select = [
    {"name": "large_cells", "classes": selected_cells_large, "well": "A1"},
    {"name": "small_cells", "classes": selected_cells_small, "well": "B1"},
]

marker_0 = (0, 0)
marker_1 = (2000, 0)
marker_2 = (0, 2000)

calibration_marker = np.array([marker_0, marker_1, marker_2])

# %%
project.selection_f.segmentation_channel_to_select = "seg_all_cytosol" #update to the correct channel for this notebook with out loading a different config
project.select(cells_to_select, calibration_marker)
# Out:
# [10/04/2025 18:42:38] Initialized temporary directory at /var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./LMDSelection_t75q4do3 for LMDSelection
# [10/04/2025 18:42:38] Selection process started.
# Processing cell batches:   0%|          | 0/3 [00:00<?, ?it/s]
# [10/04/2025 18:42:44] Temporary directory not found, skipping cleanup
# [10/04/2025 18:42:44] Temporary directory not found, skipping cleanup
# [10/04/2025 18:42:44] Temporary directory not found, skipping cleanup
# [10/04/2025 18:42:45] Coordinate lookup index calculation took 7.113560708006844 seconds.
# No configuration for shape_erosion found, parameter will be set to 0
# No configuration for binary_smoothing found, parameter will be set to 3
# No configuration for convolution_smoothing found, parameter will be set to 15
# No configuration for rdp_epsilon found, parameter will be set to 0.1
# No configuration for xml_decimal_transform found, parameter will be set to 100
# No configuration for distance_heuristic found, parameter will be set to 300
# No configuration for join_intersecting found, parameter will be set to True
# Path optimizer used for XML generation: hilbert
# cell set 0 passed sanity check
# cell set 1 passed sanity check
# Loading coordinates from external source
# Processing cell sets in parallel
# collecting cell sets:   0%|          | 0/2 [00:00<?, ?it/s]
# Convert label format into coordinate format
# Conversion finished, performing sanity check.
# Intersecting Shapes will be merged into a single shape.
# Convert label format into coordinate format
# Conversion finished, performing sanity check.
# Intersecting Shapes will be merged into a single shape.
# dilating shapes: 100%|██████████| 56/56 [00:06<00:00,  9.14it/s]]
# dilating shapes: 100%|██████████| 204/204 [00:06<00:00, 29.33it/s]
# 0 shapes that were intersecting were found and merged.
# creating shapes: 100%|██████████| 35/35 [00:03<00:00,  9.80it/s]
# calculating polygons:   0%|          | 0/35 [00:00<?, ?it/s]
# 0 shapes that were intersecting were found and merged.
# calculating polygons: 100%|██████████| 35/35 [00:06<00:00,  5.43it/s]
# Current path length: 22,206.02 units
# Optimized path length: 15,794.55 units
# Optimization factor: 1.4x
# creating shapes: 100%|██████████| 85/85 [00:04<00:00, 20.17it/s]
# Plotting shapes in debug mode is not supported in multi-threading mode.
# Saving plots to disk instead.
# calculating polygons: 100%|██████████| 85/85 [00:10<00:00,  7.98it/s]
# Current path length: 51,382.94 units
# Optimized path length: 27,741.25 units
# Optimization factor: 1.9x
# Plotting shapes in debug mode is not supported in multi-threading mode.
# Saving plots to disk instead.
# ===== Collection Stats =====
# Number of shapes: 120
# Number of vertices: 16,616
# ============================
# Mean vertices: 138
# Min vertices: 63
# 5% percentile vertices: 75
# Median vertices: 103
# 95% percentile vertices: 314
# Max vertices: 705
# [0 0]
# [      0 -200000]
# [200000      0]
# [10/04/2025 18:43:18] Saved output at /Users/sophia/Documents/GitHub/scPortrait/examples/notebooks/example_projects/example_1/project_sharded/selection/large_cells_small_cells.xml
# [10/04/2025 18:43:18] Cleaned up temporary directory at <TemporaryDirectory '/var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./LMDSelection_t75q4do3'>
